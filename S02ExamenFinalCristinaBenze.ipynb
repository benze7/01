# %% [markdown]
# # 01 Examen Final 2da Semana
#
# ### Primero hay que importar las librerias necesarias

# %%
# Importar librerias necesarias

import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# ### Ahora se tiene que cargar la BD

# %%
# Cargar la BD

MM = pd.read_csv('mortalidad.csv')   # Mortalidad Materna

# %% [markdown]
# ### Para tener una primera vista con lo que trabajaremos mostramos los encabezados de la BD

# %%
# Ver encabezados

MM.head()
# Out:
#    Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0               1972                  6                             JUNIO
# 1               1967                  2                           FEBRERO
# 2               1973                  6                             JUNIO
# 3               1966                  1                             ENERO
# 4               1975                  0                   NO ESPECIFICADO
#
#    Día de nacimiento  Genero Clave de la edad  Edad cumplida  Estado conyugal  \
# 0                 25       2                A             29                5
# 1                  1       2                A             35                5
# 2                 21       2                A             29                5
# 3                 23       2                A             36                5
# 4                  0       2                A             30                5
#
# ...

# %% [markdown]
# #### Navegamos sobre los diferentes tipos de datos contenidos en todos los campos, esto para depurar las columnas que tiene un solo tipo, o estan directamente relacionadas una a otra (Mes de nacimiento-Descripcion Mes de nacimiento)
#
# #### Con el fin de hacer una copia con menos columnas y hacer mas sencillo el analisis

# %%
# Que indicadores se dejaran para analizar

# La BD tiene muchas columnas, asi que hice una base temporal para borrar columnas y ver los encabezados de cada una fui eliminando
# asignando el resultado a una tabla temporal , borrando hasta alcanzar a ver todas las columnas

#Temp = MM.drop(['Año de nacimiento','Mes de nacimiento','Descripción del mes de nacimiento','Día de nacimiento','Genero','Clave de la edad','Edad cumplida','Estado conyugal','Descripción del estado conyugal','Entidad de residencia','Mes de registro','Descripción del mes de registro','Día de registro','Año de la certificación','Mes de la certificación','Descripció del mes de la certificación','Día de la certificación','Año de la base de datos','Razón de mortalidad materna','Descrición de la razón de mortalidad materna'], axis = 1)
#Temp = Temp.drop(['Descripción de entidad de residencia','Municipio de residencia','Descripción del municipio de residencia','Localidad de residencia','Descripión de la localidad de residencia','Tamaño de localidad','Descripción del tamaño de localidad','Ocupación habitual','Descripción de la ocupación habitual','Escolaridad','Descripción de la asistencia médica','Descrición de la causa CIE','Quien certificó','Descrición de quien certificó','Entidad de registro','Descrición de la entidad de registro','Municipio de registro','Descrición del municipio de registro','Año de registro'], axis = 1)
#Temp = Temp.drop(['Descripción de la escolaridad','Derechiahabiencia','Descrición de la derechiahabiencia','Entidad de ocurrencia','Descripción de la entidad de ocurrencia','Municipio de ocurrencia','Descrición del municipio de ocurrencia','Localidad de ocurrencia','Descrición de la localidad de ocurrencia','Sitio donde ocurrio la defunción','Descripción del sitio donde ocurrio la defunción','Año de la defunción','Mes de la defunción','Descrición del mes de la defunción','Día de la defunción','Hora de la defunción','Minutos de la defunción','Asistencia médica'], axis = 1)



#MM.head() # o bien
#pd.DataFrame(MM)   # para verlo con formato

#MM['Mes de nacimiento'].unique()
# ... para todos los campos de la BD
#MM['Descrición de la razón de mortalidad materna'].unique()

# Generar copia de BD original, depurando columnas con el mismo significado.

MM2 = MM.drop(['Mes de nacimiento','Genero','Clave de la edad','Estado conyugal','Mes de registro','Mes de la certificación','Razón de mortalidad materna','Entidad de residencia','Municipio de residencia','Municipio de registro','Localidad de residencia'], axis=1)

# %% [markdown]
# #### Mi BD depurada:

# %%
pd.DataFrame(MM2)
# hace falta depurar mas ya que aun siguen columnas sin mostrarse
# Out:
#        Año de nacimiento Descripción del mes de nacimiento  Día de nacimiento  \
# 0                   1972                             JUNIO                 25
# 1                   1967                           FEBRERO                  1
# 2                   1973                             JUNIO                 21
# 3                   1966                             ENERO                 23
# 4                   1975                   NO ESPECIFICADO                  0
# 5                   1975                   NO ESPECIFICADO                  0
# 6                   1985                   NO ESPECIFICADO                  0
# 7                   1978                             JULIO                  9
# 8                   1958                        SEPTIEMBRE                 29
# 9                   1970                              MAYO                 24
# 10                  1972                             ABRIL                 28
# ...

# %% [markdown]
# ### Parte 3: Analisis Inicial

# %%
#Nombre de los encabezados

#MM.head()
pd.DataFrame(MM)
# hay encabezados que no se alcanzan a mostrar por la dimencion de la BD
# Out:
#        Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0                   1972                  6                             JUNIO
# 1                   1967                  2                           FEBRERO
# 2                   1973                  6                             JUNIO
# 3                   1966                  1                             ENERO
# 4                   1975                  0                   NO ESPECIFICADO
# 5                   1975                  0                   NO ESPECIFICADO
# 6                   1985                  0                   NO ESPECIFICADO
# 7                   1978                  7                             JULIO
# 8                   1958                  9                        SEPTIEMBRE
# 9                   1970                  5                              MAYO
# 10                  1972                  4                             ABRIL
# ...

# %%
# Muestra un DataFrame que contenga: 
#             Edad cumplida, 
#             Descripción del estado conyugal, 
#             Tamaño de localidad, 
#             Localidad de ocurrencia, 
#             Descrición de la localidad de ocurrencia


Temp = MM.filter(items=('Edad cumplida', 'Descripción del estado conyugal', 'Tamaño de localidad', 'Localidad de ocurrencia','Descrición de la localidad de ocurrencia'))
pd.DataFrame(Temp)
# Out:
#        Edad cumplida Descripción del estado conyugal  Tamaño de localidad  \
# 0                 29                          CASADO                    9
# 1                 35                          CASADO                    9
# 2                 29                          CASADO                    4
# 3                 36                          CASADO                    1
# 4                 30                          CASADO                    0
# 5                 30                          CASADO                    0
# 6                 20                          CASADO                   12
# 7                 27                          CASADO                   15
# 8                 43                          CASADO                    1
# 9                 31                          CASADO                   13
# 10                31                          CASADO                   13
# 11                35                          CASADO                    3
# ...

# %%
#¿Cuántas edades diferentes tenían las madres cuando fallecieron? 
Edades = len(Temp['Edad cumplida'].unique())
print("La BD muestra " + str(Edades) + " edades diferentes en que las madres fallecieron")
# Out:
# La BD muestra 50 edades diferentes en que las madres fallecieron

# %%
#Obten los estadísticos para esta columna ...

Temp['Edad cumplida'].describe()
# Out:
# count    17232.000000
# mean        29.765727
# std         36.916010
# min         11.000000
# 25%         22.000000
# 50%         28.000000
# 75%         34.000000
# max        998.000000
# Name: Edad cumplida, dtype: float64

# %%
#... y los valores de las edades diferentes.

Temp['Edad cumplida'].unique()
# Out:
# array([ 29,  35,  36,  30,  20,  27,  43,  31,  39,  45,  42,  17,  38,
#         26,  21,  22,  40,  44,  34,  41,  33,  13,  24,  25,  37,  19,
#         23,  32,  28, 998,  15,  46,  48,  16,  18,  12,  47,  14,  51,
#         50,  54,  49,  11,  53,  81,  70,  82,  59,  86,  65], dtype=int64)

# %%
#Imprime los valores de los años de defunción 

#MM['Año de la base de datos'].unique()
MM['Año de la defunción'].unique()
# Out:
# array([2002, 2005, 2003, 2008, 2013, 2012, 2009, 2010, 2011, 2004, 2006,
#        2007, 2001, 1979, 1989, 1974, 1964, 1982, 1959, 1990, 1980, 1994,
#        1977, 1976, 1938, 1970, 1949, 1997, 1956, 1961, 1957, 1985, 1975,
#        2000,    0, 1948, 1971, 1978, 1984, 1993, 1992, 1972, 1973, 1986,
#        1988, 1937, 1965, 1944, 1987, 1943, 1958, 1967, 1968, 1995, 1991,
#        1969, 1999, 1966, 1963, 1953, 1954, 1962, 1950, 1996, 2014, 2015,
#        1914, 1951, 2016], dtype=int64)

# %% [markdown]
# #### ¿ Existen datos que son lógicos, es decir, están correctos?

# %%
# en edad cumplida hay una edad de 998 años, lo cual no es logico.
# tambien no se si la edad es muerte al parir, en dado caso tampoco 
#son logicas edades mayores a 50 (o algun indice de edad para poder tener embarazos)

#En año de la defuncion muestra año = cero , esto no es logico. 
#El resto de los años tiene sentido y con respecto a el campo 'Año de la base de datos'
MM.plot.scatter('Año de la defunción','Año de la base de datos')
plt.show()

# %%
#¿Cuántos tipos de escolaridad existen?


tEscolar = len(MM['Escolaridad'].unique())

print("La BD muestra " + str(tEscolar) + " diferentes tipos de escolaridad")
#MM['Descripción de la escolaridad'].unique()
# Out:
# La BD muestra 11 diferentes tipos de escolaridad

# %% [markdown]
# #### ¿Hay datos innecesarios o equivocados en la base de datos?
#
# ##### Podria pensar que son datos innecesarios los indices pero pueden ser de utilidad al momento de graficar, pero para analizar los datos es mejor utilizar los campos con descripciones

# %%
#¿Qué entidad tiene mayor número muertes?

#Contador = MM['Entidad de ocurrencia'].unique()
#print(Contador)
# MM.plot.scatter('Entidad de ocurrencia', )
#  plt.show()



# 'Entidad de ocurrencia','Descripción de la entidad de ocurrencia'

#MM.head()
#MuertesxEntidad = MM.filter(items=('Descripción de entidad de residencia'))

# plt.hist(MuertesxEntidad,30)
# plt.xlabel('Entidad')
# plt.ylabel('Número de muertes')
# plt.title('Cantidad de muertes por Entidad')
# plt.show()


#MuertesxEntidad.head()
#

#####
#ahora se hace una copia para filtrar los indicadores y mover indices

# PARA INDICADOR Entidad de ocurrencia
#M2 = MM.set_index('Descripción de la entidad de ocurrencia') 
#M2
# solo un indicador
#M2 = M2.loc['  ']
#M2
# cambiar el indice
#M2 = M2.set_index('   ')
#M2

# M2['Genero'].plot(kind='bar')
# plt.title('Entidad de ocurrencia')
# # plt.xlabel('')
# # plt.ylabel('')
# plt.show()

# %% [markdown]
# ### Parte 4 - Búsqueda de datos
# ####  Se hace un extracto de la base de datos con las siguientes columnas
#
#  - 'Descripción del estado conyugal',
#  - 'Edad cumplida',
#  - 'Descrición de la razón de mortalidad materna',
#  - 'Descripión de la localidad de residencia',
#  - 'Tamaño de localidad',
#  - 'Descripción del tamaño de localidad',
#  - 'Descripción de la escolaridad',
#  - 'Descrición de quien certificó',
#  - 'Descripción de la asistencia médica',
#  - 'Descripción de la entidad de ocurrencia',
#  - 'Descripción del sitio donde ocurrio la defunción'
#
#
# #### Se incluye la entidad de residencia y la entidad de la ocurrencia, para buscar la relacion si fue cerca o lejos de su hogar

# %%
Entidad = MM.filter(items=('Descrición de la razón de mortalidad materna','Descripión de la localidad de residencia','Descripción de la entidad de ocurrencia'))
pd.DataFrame(Entidad)
# Out:
#             Descrición de la razón de mortalidad materna  \
# 0      Muertes Maternas para la razón de Mortalidad M...
# 1      Muertes Maternas para la razón de Mortalidad M...
# 2      Muertes Maternas para la razón de Mortalidad M...
# 3      Muertes Maternas para la razón de Mortalidad M...
# 4      Muertes Maternas para la razón de Mortalidad M...
# 5      Muertes Maternas para la razón de Mortalidad M...
# 6      Muertes Maternas para la razón de Mortalidad M...
# 7      Muertes Maternas para la razón de Mortalidad M...
# 8      Muertes Maternas para la razón de Mortalidad M...
# 9      Muertes Maternas para la razón de Mortalidad M...
# 10     Muertes Maternas para la razón de Mortalidad M...
# 11     Muertes Maternas para la razón de Mortalidad M...
# 12     Muertes Maternas para la razón de Mortalidad M...
# 13     Muertes Maternas para la razón de Mortalidad M...
# 14     Muertes Maternas excluidas para la razón de Mo...
# ...

# %% [markdown]
# #### Se incluye estado civil, escolaridad, edad, tamaño de localidad y asistencia medica para buscar si el indice es mas alto en alguna de estas clasificaciones

# %%
Factores = MM.filter(items=('Descripción del estado conyugal','Edad cumplida','Descrición de la razón de mortalidad materna','Descripción del tamaño de localidad','Descripción de la escolaridad','Descrición de quien certificó','Descripción de la asistencia médica'))
pd.DataFrame(Factores)
# Out:
#       Descripción del estado conyugal  Edad cumplida  \
# 0                              CASADO             29
# 1                              CASADO             35
# 2                              CASADO             29
# 3                              CASADO             36
# 4                              CASADO             30
# 5                              CASADO             30
# 6                              CASADO             20
# 7                              CASADO             27
# 8                              CASADO             43
# 9                              CASADO             31
# 10                             CASADO             31
# 11                             CASADO             35
# 12                             CASADO             39
# 13                             CASADO             29
# 14                             CASADO             45
# 15                             CASADO             42
# 16                             CASADO             17
# ...

# %% [markdown]
# ### Parte 5 - Información gráfica

# %%
# esto no termino de cargarse :(   )

AtencionMedica = Factores['Descripción de la asistencia médica']

plt.hist(AtencionMedica)
plt.xlabel('Atencion Medica')
plt.ylabel('Número')
plt.title('Número')
plt.show()

# PARA INDICADOR Entidad de ocurrencia
#Temp2 = Factores.set_index('Descripción de la asistencia médica') 
#Temp2


# solo un indicador
#o2 = o2.loc['JE_LMIS']
#o2
# cambiar el indice
#o2 = o2.set_index('LOCATION')
#o2

# M2['Genero'].plot(kind='bar')
# plt.title('Entidad de ocurrencia')
# # plt.xlabel('')
# # plt.ylabel(e')
# plt.show()

# %%
# como tarda mucho en mostrarme la grafica, intentare con los indices

Factores2 = MM.filter(items=('Estado conyugal','Edad cumplida','Razón de mortalidad materna','Tamaño de localidad','Escolaridad','Quien certificó','Asistencia médica'))
pd.DataFrame(Factores2)

# %%
# Realicen una análisis de correlación para 4 variables

Factores2.plot.scatter('Estado conyugal','Edad cumplida','Asistencia médica','Tamaño de localidad')
plt.show()
